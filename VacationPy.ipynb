# %%
# !jupyter nbextension enable --py --sys-prefix widgetsnbextension
# !jupyter nbextension enable --py --sys-prefix gmaps

# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: ok
# Enabling notebook extension jupyter-gmaps/extension...
#       - Validating: ok

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID                City Country                 Date      Lat  \
# 0        0  Havre-Saint-Pierre      CA  2021-10-11 12:42:54  50.2334
# 1        1             Ushuaia      AR  2021-10-11 12:41:47 -54.8000
# 2        2               Bluff      NZ  2021-10-11 12:43:17 -46.6000
# 3        3        Longyearbyen      SJ  2021-10-11 12:43:47  78.2186
# 4        4          Nanortalik      GL  2021-10-11 12:42:54  60.1432
#
#         Lng  Max Temp  Humidity  Cloudiness  Wind Speed
# 0  -63.5986     54.19       100          90        2.30
# 1  -68.3000     44.26        76          40        3.44
# 2  168.3333     43.81        73         100       25.55
# 3   15.6401     31.84        69          75       18.41
# 4  -45.2371     42.01        45         100        4.27

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
# Assign the figure variable.
fig = gmaps.figure()
# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp], dissipating=False, max_intensity=300, point_radius=4)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
clouds = city_data_df["Cloudiness"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=clouds, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
wind = city_data_df["Wind Speed"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=wind, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID        City Country                 Date      Lat       Lng  \
# 6         6      Tiarei      PF  2021-10-11 12:44:56 -17.5333 -149.3333
# 7         7  Butaritari      KI  2021-10-11 12:43:40   3.0707  172.7902
# 9         9    Hermanus      ZA  2021-10-11 12:42:51 -34.4187   19.2345
# 13       13    Lorengau      PG  2021-10-11 12:44:58  -2.0226  147.2712
# 14       14  Georgetown      MY  2021-10-11 12:42:44   5.4112  100.3354
# 18       18   Wattegama      LK  2021-10-11 12:44:59   6.7989   81.4808
# 19       19      Banjar      ID  2021-10-11 12:44:59  -8.1900  114.9675
# 22       22   Kavaratti      IN  2021-10-11 12:43:15  10.5669   72.6420
# 23       23  Sao Filipe      CV  2021-10-11 12:45:00  14.8961  -24.4956
# 26       26    Coruripe      BR  2021-10-11 12:45:04 -10.1256  -36.1756
#
#     Max Temp  Humidity  Cloudiness  Wind Speed
# 6      75.22        76         100       13.80
# 7      81.30        70         100        7.78
# 9      82.80        50         100        5.97
# 13     81.68        76          42        4.74
# 14     85.98        72          20        1.99
# 18     83.32        67         100        6.06
# 19     78.66        85         100        9.42
# 22     81.19        83         100       15.39
# 23     81.99        67           0        8.37
# 26     84.67        62          94       11.56

# %%
preferred_cities_df.count()
# Out:
# City_ID       191
# City          191
# Country       189
# Date          191
# Lat           191
# Lng           191
# Max Temp      191
# Humidity      191
# Cloudiness    191
# Wind Speed    191
# dtype: int64

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#           City Country  Max Temp      Lat       Lng Hotel Name
# 6       Tiarei      PF     75.22 -17.5333 -149.3333
# 7   Butaritari      KI     81.30   3.0707  172.7902
# 9     Hermanus      ZA     82.80 -34.4187   19.2345
# 13    Lorengau      PG     81.68  -2.0226  147.2712
# 14  Georgetown      MY     85.98   5.4112  100.3354
# 18   Wattegama      LK     83.32   6.7989   81.4808
# 19      Banjar      ID     78.66  -8.1900  114.9675
# 22   Kavaratti      IN     81.19  10.5669   72.6420
# 23  Sao Filipe      CV     81.99  14.8961  -24.4956
# 26    Coruripe      BR     84.67 -10.1256  -36.1756

# %%
requests.get('https://maps.googleapis.com/maps/api/place/nearbysearch/json', params= {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
})
# Out:
# <Response [200]>

# %%
# Set parameters to search for a hotel.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# %%
# Set the parameters to search for a hotel in Paris.
params = {
    "radius": 5000,
    "types": "lodging",
    "key": g_key,
    "location": "48.8566, 2.3522"}

# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    # Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")

# Use base URL to search for hotels in Paris.
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
# Make request and get the JSON data from the search.
hotels = requests.get(base_url, params=params).json()

hotels
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# {'html_attributions': [],
#  'next_page_token': 'Aap_uEAiDtQI6dNiqRifyVLv7nQwNj0O2jhNQ4TYK4JTsXBdAlYPCYi0QgDsM93NSOJ952IDF0o-kUbhE6gQQvfZ9OhrHUgGEEPjWksMHNZlJeZ7aUJvkXntVESV3_rT96HOdXYI2nPNf2rqhlQOZEChQRtrm9O_keJgbj6_IqTL7Vk4yXHpfZpvkAPc-Qe6M0ggeyyx0VPG9LrCVhRqorloCU94LpRxPhDjaaFIQR_45rD8zvNzOUlrWid-bDSuctdH97aNYfhlWc9IgGjq8G_Fd4gl1xABikgHeg-687FwG4FgK7AP1-XX12HCdwhfvpKGHqeyEchA68qt3j1LaG0oMvHVdjjuMp3u7KkZtM3wzbMVqp9j1djgwRue3qhgpN0gx7GtUJP46cYZkeS-XFGH7n-pLELc8b_oHhDt5ZXp3P55oS2xiGO3XGZB',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 0.3607816, 'lng': 37.6033795},
#     'viewport': {'northeast': {'lat': 0.362432830291502,
#       'lng': 37.6048383802915},
#      'southwest': {'lat': 0.3597348697084979, 'lng': 37.6021404197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Gaddisa Hotel',
#    'photos': [{'height': 4160,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101766401779702641704">John Gitumbi</a>'],
#      'photo_reference': 'Aap_uEB3r8jrMLRJJ6Mo97hhQ7vMK5ZIAuguTGbHx24neTUAOoub8hue9q0jewtDsuPqsxbrHma3CJqKuNr9GgAkaHKeNLqInLiNQSVSvm0ZTLx0a2hdNSbQKXi9ZH44sqUEBgr7chzDXs4BBrsGEcejuUGC2fSW4h-NdnbCtFzS8PzrZpo',
#      'width': 3120}],
#    'place_id': 'ChIJ6UfUMdFniBcRLurZF5KnsuM',
#    'plus_code': {'compound_code': '9J63+89 Isiolo, Kenya',
#     'global_code': '6GGV9J63+89'},
#    'rating': 2.8,
#    'reference': 'ChIJ6UfUMdFniBcRLurZF5KnsuM',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 14,
#    'vicinity': 'Isiolo - Mandera Road, Isiolo'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 0.355639, 'lng': 37.583305},
#     'viewport': {'northeast': {'lat': 0.3569883802915021,
#       'lng': 37.5846241802915},
#      'southwest': {'lat': 0.354290419708498, 'lng': 37.5819262197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Shamz Hotel-Isiolo',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3968,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107796417494969794750">MarkDenver</a>'],
#      'photo_reference': 'Aap_uEBy3ehT8wiyZ6zbmzHYvEhGCNeLvfCjdKEM4Bpugi_h0hSzAiM7hK_fBS3nrztoE0eMbHtBWtRx4SEApO2B0_C3gysXCGNVr-Yh5jeLWP7wsNln9FgsQmewqdevukSZp3VYLu30fII_Np2hIsRig5LR7HwwH5XncGM2f7nS5Z-zsZvF',
#      'width': 2976}],
#    'place_id': 'ChIJa2DYDZ1oiBcRPaUS_oZZQEU',
#    'plus_code': {'compound_code': '9H4M+78 Isiolo, Kenya',
#     'global_code': '6GGV9H4M+78'},
#    'rating': 3.6,
#    'reference': 'ChIJa2DYDZ1oiBcRPaUS_oZZQEU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 78,
#    'vicinity': 'Wabera Airport Rd, Isiolo'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 0.336535, 'lng': 37.578545},
#     'viewport': {'northeast': {'lat': 0.3379514802915021,
#       'lng': 37.5797914802915},
#      'southwest': {'lat': 0.335253519708498, 'lng': 37.5770935197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Northern Galaxy Hotel-Isiolo',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1536,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110585750632029658717">Mark Baiywoh</a>'],
#      'photo_reference': 'Aap_uEDAYRv2o9yirIfNgebd-3Rbb0JVxG04mUcUp7eUYUAW3CQo-I2khlUUxp7oVRbMumf_Aly2owlFyRGxvMITlgPEY9d9npKOG0OhpStWLtp-x9LbIN_Nz8cybpz29NZa7IXDeigz-HvKts7UBhbLIo-NtGeOaU1lNP6CKR9sftyJt9fx',
#      'width': 2048}],
#    'place_id': 'ChIJX__IVQ9piBcRGvxGB2xFzpg',
#    'plus_code': {'compound_code': '8HPH+JC Isiolo, Kenya',
#     'global_code': '6GGV8HPH+JC'},
#    'rating': 3.7,
#    'reference': 'ChIJX__IVQ9piBcRGvxGB2xFzpg',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 546,
#    'vicinity': 'Oldo/Nyiro, Kenyatta Highway, Isiolo'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 0.3535578, 'lng': 37.5821736},
#     'viewport': {'northeast': {'lat': 0.3549033302915021,
#       'lng': 37.5836224302915},
#      'southwest': {'lat': 0.352205369708498, 'lng': 37.5809244697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Isiolo Prestige Hotel',
#    'photos': [{'height': 4160,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100225239399609286569">Noor Adan</a>'],
#      'photo_reference': 'Aap_uED8fC8MxyV44mGDM6khgnIpFMXF_d8SlIn4DXsxRL7_ay6oF5Gy9agkhQOmY07Pxre4JmUnE8bpm_oRZBeWc39BJQ0duAbW5HjWyfU40mxQGBiXqq5zOiaJIgg4VogxHH2m_2JKV0VFSEYRLN4ZVxj_8mAqNPpacjQ9b5B37p83Xu2Q',
#      'width': 1872}],
#    'place_id': 'ChIJQee2CHtpiBcRD63RKGM860U',
#    'rating': 3.5,
#    'reference': 'ChIJQee2CHtpiBcRD63RKGM860U',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': '9H3J+CVF, Isiolo'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 0.3546304000000001, 'lng': 37.5834081},
#     'viewport': {'northeast': {'lat': 0.3559801302915021,
#       'lng': 37.5847014802915},
#      'southwest': {'lat': 0.353282169708498, 'lng': 37.5820035197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Isiolo High class Highway Lodge',
#    'place_id': 'ChIJMVA0-5xoiBcRWs_RqlXK3Ac',
#    'plus_code': {'compound_code': '9H3M+V9 Isiolo, Kenya',
#     'global_code': '6GGV9H3M+V9'},
#    'rating': 4.7,
#    'reference': 'ChIJMVA0-5xoiBcRWs_RqlXK3Ac',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 6,
#    'vicinity': 'A2, Isiolo'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 0.3551580000000001,
#      'lng': 37.58330000000001},
#     'viewport': {'northeast': {'lat': 0.3565073302915021,
#       'lng': 37.5846216802915},
#      'southwest': {'lat': 0.353809369708498, 'lng': 37.5819237197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'MOCHARO HOTEL',
#    'place_id': 'ChIJqyBjA51oiBcRfkeGwLE743M',
#    'reference': 'ChIJqyBjA51oiBcRfkeGwLE743M',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '9H4M+387, Isiolo'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 0.3551580000000001,
#      'lng': 37.58330000000001},
#     'viewport': {'northeast': {'lat': 0.3565073302915021,
#       'lng': 37.5846216802915},
#      'southwest': {'lat': 0.353809369708498, 'lng': 37.5819237197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'DESMAK HOTEL',
#    'place_id': 'ChIJqyBjA51oiBcRrqB-_s3S9hI',
#    'reference': 'ChIJqyBjA51oiBcRrqB-_s3S9hI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '9H4M+387, Isiolo'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 0.3551580000000001,
#      'lng': 37.58330000000001},
#     'viewport': {'northeast': {'lat': 0.3565073302915021,
#       'lng': 37.5846216802915},
#      'southwest': {'lat': 0.353809369708498, 'lng': 37.5819237197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'CLUB 280',
#    'place_id': 'ChIJqyBjA51oiBcRQ80Yd2Ln8MY',
#    'plus_code': {'compound_code': '9H4M+38 Isiolo, Kenya',
#     'global_code': '6GGV9H4M+38'},
#    'rating': 3.5,
#    'reference': 'ChIJqyBjA51oiBcRQ80Yd2Ln8MY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': 'MOYALE, ROAD, Isiolo'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 0.3551580000000001,
#      'lng': 37.58330000000001},
#     'viewport': {'northeast': {'lat': 0.3565073302915021,
#       'lng': 37.5846216802915},
#      'southwest': {'lat': 0.353809369708498, 'lng': 37.5819237197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'MOCHARO HOTEL',
#    'place_id': 'ChIJqyBjA51oiBcRiaX-JOaAq6s',
#    'reference': 'ChIJqyBjA51oiBcRiaX-JOaAq6s',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '9H4M+387, Isiolo'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 0.3551580000000001,
#      'lng': 37.58330000000001},
#     'viewport': {'northeast': {'lat': 0.3565073302915021,
#       'lng': 37.5846216802915},
#      'southwest': {'lat': 0.353809369708498, 'lng': 37.5819237197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'DESMAK HOTEL',
#    'place_id': 'ChIJqyBjA51oiBcRYrUMLylpADw',
#    'reference': 'ChIJqyBjA51oiBcRYrUMLylpADw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '9H4M+387, Isiolo'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 0.3552770000000001,
#      'lng': 37.58330000000001},
#     'viewport': {'northeast': {'lat': 0.3566263302915021,
#       'lng': 37.5846232802915},
#      'southwest': {'lat': 0.353928369708498, 'lng': 37.5819253197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'WASO CENTRAL EMPORIUM LODGE',
#    'place_id': 'ChIJfcPiBJ1oiBcRAZ3SH4kXtYk',
#    'reference': 'ChIJfcPiBJ1oiBcRAZ3SH4kXtYk',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '9H4M+487, Isiolo'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 0.355636, 'lng': 37.5833061},
#     'viewport': {'northeast': {'lat': 0.356985380291502,
#       'lng': 37.5846240802915},
#      'southwest': {'lat': 0.3542874197084979, 'lng': 37.5819261197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Sera Park Hotel isiolo',
#    'place_id': 'ChIJJ3W7wSppiBcRGpR-6FXawVI',
#    'plus_code': {'compound_code': '9H4M+78 Isiolo, Kenya',
#     'global_code': '6GGV9H4M+78'},
#    'rating': 3,
#    'reference': 'ChIJJ3W7wSppiBcRGpR-6FXawVI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': 'Isiolo'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 0.355636, 'lng': 37.5833061},
#     'viewport': {'northeast': {'lat': 0.356985380291502,
#       'lng': 37.5846240802915},
#      'southwest': {'lat': 0.3542874197084979, 'lng': 37.5819261197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/camping-71.png',
#    'icon_background_color': '#4DB546',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/camping_pinlet',
#    'name': 'Mount Kenya Wanderer',
#    'place_id': 'ChIJV4IjlDJpiBcR2tlDLtUS7Yc',
#    'plus_code': {'compound_code': '9H4M+78 Isiolo, Kenya',
#     'global_code': '6GGV9H4M+78'},
#    'reference': 'ChIJV4IjlDJpiBcR2tlDLtUS7Yc',
#    'scope': 'GOOGLE',
#    'types': ['campground',
#     'lodging',
#     'park',
#     'point_of_interest',
#     'establishment'],
#    'vicinity': 'Subuiga-Isiolo main road'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 0.355636, 'lng': 37.5833061},
#     'viewport': {'northeast': {'lat': 0.356985380291502,
#       'lng': 37.5846240802915},
#      'southwest': {'lat': 0.3542874197084979, 'lng': 37.5819261197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'skyview hotel isiolo',
#    'place_id': 'ChIJrwYGKvBpiBcRzZjbH1-2qqc',
#    'plus_code': {'compound_code': '9H4M+78 Isiolo, Kenya',
#     'global_code': '6GGV9H4M+78'},
#    'reference': 'ChIJrwYGKvBpiBcRzZjbH1-2qqc',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'down town'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 0.355636, 'lng': 37.5833061},
#     'viewport': {'northeast': {'lat': 0.356985380291502,
#       'lng': 37.5846240802915},
#      'southwest': {'lat': 0.3542874197084979, 'lng': 37.5819261197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Gateway lounge isiolo',
#    'place_id': 'ChIJcZ12LA9piBcRH1KNZFYbzA0',
#    'plus_code': {'compound_code': '9H4M+78 Isiolo, Kenya',
#     'global_code': '6GGV9H4M+78'},
#    'rating': 4,
#    'reference': 'ChIJcZ12LA9piBcRH1KNZFYbzA0',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'Gate way lounge, Isiolo'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 0.355636, 'lng': 37.5833061},
#     'viewport': {'northeast': {'lat': 0.356985380291502,
#       'lng': 37.5846240802915},
#      'southwest': {'lat': 0.3542874197084979, 'lng': 37.5819261197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Jamhuri Guest House',
#    'place_id': 'ChIJ9YQO7qJpiBcRK3DNIlp3CLc',
#    'plus_code': {'compound_code': '9H4M+78 Isiolo, Kenya',
#     'global_code': '6GGV9H4M+78'},
#    'reference': 'ChIJ9YQO7qJpiBcRK3DNIlp3CLc',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Consolidated'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 0.3557053000000001,
#      'lng': 37.58330749999999},
#     'viewport': {'northeast': {'lat': 0.3570546802915021,
#       'lng': 37.5846249802915},
#      'southwest': {'lat': 0.354356719708498, 'lng': 37.5819270197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'wathiras house',
#    'place_id': 'ChIJPXLtWn9piBcRdcPx-C9txSw',
#    'plus_code': {'compound_code': '9H4M+78 Isiolo, Kenya',
#     'global_code': '6GGV9H4M+78'},
#    'reference': 'ChIJPXLtWn9piBcRdcPx-C9txSw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'downtown, Isiolo'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 0.3557069, 'lng': 37.58335409999999},
#     'viewport': {'northeast': {'lat': 0.3570560802915021,
#       'lng': 37.5846879802915},
#      'southwest': {'lat': 0.354358119708498, 'lng': 37.5819900197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'AL-BADR PLAZA',
#    'photos': [{'height': 2048,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116761818131553993881">chari investments ltd</a>'],
#      'photo_reference': 'Aap_uEBaVmvWNPTB0-LkWi35-vwFJh6UeBfLGkZC5eNPCBdVe-Vagt8NOOXE0QWzcPI42Z9v_cACcMHveOq-HaLZEfRlKpMBrKYdnDDfK4mSn5w6FjYIhSF1cHEYjJmEhsiLx1OKJht_HYo8jUKRQE4dNBIalvsRWCfNLOjVdGDnLsLNpIKK',
#      'width': 1536}],
#    'place_id': 'ChIJa2DYDZ1oiBcRBceqJIzLRoc',
#    'rating': 5,
#    'reference': 'ChIJa2DYDZ1oiBcRBceqJIzLRoc',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 3,
#    'vicinity': '9H4M+78Q, Isiolo'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 0.3524947, 'lng': 37.5831409},
#     'viewport': {'northeast': {'lat': 0.3538381302915021,
#       'lng': 37.5845498302915},
#      'southwest': {'lat': 0.351140169708498, 'lng': 37.5818518697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'MADIBAS restaurant',
#    'photos': [{'height': 3840,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101162085123245640925">Francis Njenga</a>'],
#      'photo_reference': 'Aap_uECrL7hgJqk-RSxB9ywTYSbwcwag5AZ2wdt4jbVECMy4N3Zlhy7Xmz0dS3lOQYpzRZ1t2nD32xP325cH2NrGdgx9OxBqu-NJ9zAb2mwRLrQHVt31JTwP5RhHMkWeMhIj0p_5B4ySqd_BRAXRGJsjszsvnhWLhdtDw4GpuoupOygvgwiv',
#      'width': 2160}],
#    'place_id': 'ChIJCwMfsX9piBcRgpl2b_fH04g',
#    'plus_code': {'compound_code': '9H2M+X7 Isiolo, Kenya',
#     'global_code': '6GGV9H2M+X7'},
#    'rating': 4,
#    'reference': 'ChIJCwMfsX9piBcRgpl2b_fH04g',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': 'Bulla Pesa'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 0.3524632, 'lng': 37.5834376},
#     'viewport': {'northeast': {'lat': 0.353736630291502,
#       'lng': 37.5848021802915},
#      'southwest': {'lat': 0.351038669708498, 'lng': 37.5821042197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Waso Executive Lodge',
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117359909810479169325">Jotham K. Kirwa</a>'],
#      'photo_reference': 'Aap_uED3tZK1E0ToPgIpfVMIedNkaRyIOrroptaWXOR4dTPkyzR-rmIUsGbNWVF0BfzTrA2ApiCLmAjsfOQgKw_SiS0P8uxvxgNl8MKZLqawygLHKB3TTXdi-ZKJaqv5l1E7Orowg_EMqca1pjcxcKQYKIoNuN-7WouLDFkN0-I46JFRBAxC',
#      'width': 3047}],
#    'place_id': 'ChIJp0O-AiNpiBcRbibW7dRCFNU',
#    'plus_code': {'compound_code': '9H2M+X9 Isiolo, Kenya',
#     'global_code': '6GGV9H2M+X9'},
#    'rating': 4.6,
#    'reference': 'ChIJp0O-AiNpiBcRbibW7dRCFNU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 5,
#    'vicinity': 'Hospital Road, Isiolo'}],
#  'status': 'OK'}

# %%
# Add a heatmap of temperature for the vacation spots.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False,
             max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Add a heatmap of temperature for the vacation spots and marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,
             dissipating=False, max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# %%
# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
